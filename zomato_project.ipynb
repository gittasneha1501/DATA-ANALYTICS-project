# %%
import pandas as pd
df=pd.read_csv(r"/content/zomato.csv")
print(df)
# Out:
#       Unnamed: 0.1  Unnamed: 0         restaurant name     restaurant type  \
# 0                0           0            #FeelTheROLL         Quick Bites
# 1                1           1              #L-81 Cafe         Quick Bites
# 2                2           2                 #refuel                Cafe
# 3                3           3      '@ Biryani Central       Casual Dining
# 4                4           4              '@ The Bbq       Casual Dining
# ...            ...         ...                     ...                 ...
# 7100          7100        7100                  Zoey's                Cafe
# 7101          7101        7101  ZOROY Luxury Chocolate      Dessert Parlor
# 7102          7102        7102       Zu's Doner Kebaps  Takeaway, Delivery
# 7103          7103        7103                   Zyara       Casual Dining
# 7104          7104        7104                  Zyksha          Food Truck
#
# ...

# %%
print(df.head(25)) #top rows
print(df.tail(25))   #bottom rows
# Out:
#     Unnamed: 0.1  Unnamed: 0                       restaurant name  \
# 0              0           0                          #FeelTheROLL
# 1              1           1                            #L-81 Cafe
# 2              2           2                               #refuel
# 3              3           3                    '@ Biryani Central
# 4              4           4                            '@ The Bbq
# 5              5           5                                  '@99
# 6              6           6                               '@Italy
# 7              7           7                  '@North Parontha Hut
# 8              8           8                              1000 B.C
# 9              9           9  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
# 10            10          10            11 to 11 Express Biriyanis
# 11            11          11                    1131 Bar + Kitchen
# 12            12          12             12th Main - Grand Mercure
# ...

# %%
print(df.info())  #quick way to look datatypes,missing values,data size
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           7105 non-null   int64
#  1   Unnamed: 0             7105 non-null   int64
#  2   restaurant name        7105 non-null   object
#  3   restaurant type        7105 non-null   object
#  4   rate (out of 5)        7037 non-null   float64
#  5   num of ratings         7105 non-null   int64
#  6   avg cost (two people)  7048 non-null   float64
#  7   online_order           7105 non-null   object
#  8   table booking          7105 non-null   object
#  9   cuisines type          7105 non-null   object
#  10  area                   7105 non-null   object
#  11  local address          7105 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 666.2+ KB
# None

# %%
print(df.shape)   #no.of rows and columns
print(df.shape[0])  #no.of rows
print(df.shape[1])  #no.of columns
# Out:
# (7105, 12)
# 7105
# 12

# %%
print(df.columns)   #column names
print(list(df.columns))   #convert to list
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'restaurant name', 'restaurant type',
#        'rate (out of 5)', 'num of ratings', 'avg cost (two people)',
#        'online_order', 'table booking', 'cuisines type', 'area',
#        'local address'],
#       dtype='object')
# ['Unnamed: 0.1', 'Unnamed: 0', 'restaurant name', 'restaurant type', 'rate (out of 5)', 'num of ratings', 'avg cost (two people)', 'online_order', 'table booking', 'cuisines type', 'area', 'local address']

# %%
#checking for missing values
print(df.isnull().head(20))
print(df.isna().sum())   #null values & adding
# Out:
#     Unnamed: 0.1  Unnamed: 0  restaurant name  restaurant type  \
# 0          False       False            False            False
# 1          False       False            False            False
# 2          False       False            False            False
# 3          False       False            False            False
# 4          False       False            False            False
# 5          False       False            False            False
# 6          False       False            False            False
# 7          False       False            False            False
# 8          False       False            False            False
# 9          False       False            False            False
# 10         False       False            False            False
# 11         False       False            False            False
# 12         False       False            False            False
# 13         False       False            False            False
# ...

# %%
#slicing & extracting data

##isolating columns

print(df['restaurant type'].head(10))    #one column
print(df[['cuisines type','rate (out of 5)']].head(10))   #multiple column

##isolating rows
print(df[df.index==25])
# Out:
# 0           Quick Bites
# 1           Quick Bites
# 2                  Cafe
# 3         Casual Dining
# 4         Casual Dining
# 5    Takeaway, Delivery
# 6         Casual Dining
# 7    Takeaway, Delivery
# 8           Quick Bites
# 9         Casual Dining
# Name: restaurant type, dtype: object
#                                        cuisines type  rate (out of 5)
# 0                                          Fast Food              3.4
# 1                               Fast Food, Beverages              3.9
# 2                                    Cafe, Beverages              3.7
# 3                          Biryani, Mughlai, Chinese              2.7
# 4  BBQ, Continental, North Indian, Chinese, Bever...              2.8
# 5            Mughlai, Biryani, Chinese, North Indian              3.4
# 6                                            Italian              4.1
# 7                                       North Indian              2.8
# ...

# %%
#using.loc to fetch rows
print(df.loc[15])
print(df.loc[12:18])
print(df.iloc[9])
print(df.iloc[6:14])
# Out:
# Unnamed: 0.1                                         15
# Unnamed: 0                                           15
# restaurant name                      154 Breakfast Club
# restaurant type                                    Cafe
# rate (out of 5)                                     4.0
# num of ratings                                     1509
# avg cost (two people)                             900.0
# online_order                                        Yes
# table booking                                       Yes
# cuisines type                         Cafe, Continental
# area                     Byresandra,Tavarekere,Madiwala
# local address                     Koramangala 3rd Block
# Name: 15, dtype: object
#     Unnamed: 0.1  Unnamed: 0            restaurant name restaurant type  \
# 12            12          12  12th Main - Grand Mercure     Fine Dining
# 13            13          13              1441 Pizzeria   Casual Dining
# ...

# %%
#dealing with missing values
##dropping missing values
data1=df.dropna()
print(data1.isnull().sum())
df.dropna(inplace=True,axis=0)
print(df.isnull().sum())
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# restaurant name          0
# restaurant type          0
# rate (out of 5)          0
# num of ratings           0
# avg cost (two people)    0
# online_order             0
# table booking            0
# cuisines type            0
# area                     0
# local address            0
# dtype: int64
# Unnamed: 0.1             0
# Unnamed: 0               0
# restaurant name          0
# restaurant type          0
# rate (out of 5)          0
# num of ratings           0
# avg cost (two people)    0
# online_order             0
# table booking            0
# cuisines type            0
# area                     0
# local address            0
# dtype: int64

# %%
#replacing mean
mean_value=df['avg cost (two people)'].mean()
print(mean_value)
#replacing median
median_value=df['num of ratings'].median()
print(median_value)
# Out:
# 542.5442439862543
# 40.0

# %%
#renaming column
df.rename(columns={'avg cost (two people)':'avg cost'},inplace=True)
df.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0                       restaurant name  \
# 0              0           0                          #FeelTheROLL
# 1              1           1                            #L-81 Cafe
# 2              2           2                               #refuel
# 3              3           3                    '@ Biryani Central
# 4              4           4                            '@ The Bbq
# 5              5           5                                  '@99
# 6              6           6                               '@Italy
# 7              7           7                  '@North Parontha Hut
# 8              8           8                              1000 B.C
# 9              9           9  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
# 10            10          10            11 to 11 Express Biriyanis
# 11            11          11                    1131 Bar + Kitchen
# 12            12          12             12th Main - Grand Mercure
# ...

# %%
#value.counts()
df['area'].value_counts()
# Out:
# area
# Byresandra,Tavarekere,Madiwala    794
# Bannerghatta Road                 552
# Brookefield                       477
# Brigade Road                      463
# Indiranagar                       450
# Electronic City                   402
# Malleshwaram                      401
# Kalyan Nagar                      379
# Bellandur                         359
# Banashankari                      359
# Marathahalli                      258
# Whitefield                        257
# HSR                               238
# Basavanagudi                      198
# New BEL Road                      166
# Koramangala 4th Block             160
# Rajajinagar                       145
# Lavelle Road                      140
# Jayanagar                         126
# Frazer Town                       124
# Sarjapur Road                     107
# Old Airport Road                   82
# Church Street                      76
# JP Nagar                           68
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))
sns.countplot(x='rate (out of 5)', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(14,5))
sns.countplot(x='online_order', data=df,hue='avg cost')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lineplot(x='restaurant type',y='rate (out of 5)',data=df)
# Out:
# <Axes: xlabel='restaurant type', ylabel='rate (out of 5)'>

# %%
sns.barplot(y='avg cost',x='online_order',data=df)
# Out:
# <Axes: xlabel='online_order', ylabel='avg cost'>

# %%
sns.boxplot(x='table booking',y='avg cost',data=df)
# Out:
# <Axes: xlabel='table booking', ylabel='avg cost'>

# %%
sns.violinplot(y='num of ratings',x='online_order',data=df)
# Out:
# <Axes: xlabel='online_order', ylabel='num of ratings'>

# %%
sns.histplot(y='avg cost',data=df,kde=True)
# Out:
# <Axes: xlabel='Count', ylabel='avg cost'>
